# %% [markdown]
# # Intervjufrågor – cybersäkerhet inom konsult/rekrytering
#
# ## Om verksamheten
# * Kan ni kort beskriva vilken typ av information och data ni hanterar i er verksamhet?
# * Vilka är era mest affärskritiska system, och hur stor frihet har olika avdelningar (t.ex. marknad, konferens, reception) att välja egna digitala verktyg för sitt dagliga arbete?
# * Vilken information skulle ni säga är mest känslig eller viktig att skydda?
#
# ---
#
# ## Cybersäkerhet
# 4. Hur arbetar ni med cybersäkerhet idag?
#    * **4a)** Hur har cybersäkerhetsarbetet förändrats och varför?
# 5. Vilka cybersäkerhetsrisker upplever ni som störst i er verksamhet?
#    * **5a)** Varför är dessa risker störst?
# 6. Vilka typer av säkerhetsincidenter eller misstag är ni mest oroliga för?
# 7. Hur arbetar ni för att få medarbetare att följa säkerhetsrutiner?
# 8. Upplever ni att det finns en skillnad mellan era säkerhetspolicyer och hur medarbetarna faktiskt arbetar i vardagen?
#    * **8a)** Om ja, varför tror du det finns en skillnad?
#
# * Använder ni er av något etablerat ramverk i cybersäkerhetsarbetet? Till exempel NIST eller Zero-trust och i så fall hur återspeglas det i det dagliga arbetet?
#
# ---
#
# ## Data & GDPR
# 9. Vilka är de största utmaningarna kring hantering av personuppgifter och annan känslig information?
# 11. Hur hanterar ni information när den behöver delas med kunder, konsulter eller externa leverantörer?
#
# ---
#
# ## AI & digitala verktyg
# 12. Hur använder ni AI i verksamheten idag?
# 13. Finns det riktlinjer för vilka AI-verktyg medarbetare får använda och vilken information de får mata in?
# 14. Hur säkerställer ni att medarbetare inte använder externa verktyg eller AI-tjänster på ett sätt som kan innebära en säkerhetsrisk?
#
# ---
#
# ## Hitta projektets problemområde
# 16. Finns det något säkerhetsproblem ni upplever att ni vet finns, men som är svårt att lösa?
# 17. Var upplever ni störst brist på kontroll eller överblick?
